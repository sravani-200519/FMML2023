# %% [markdown]
# <a href="https://colab.research.google.com/github/sravani-200519/FMML2023/blob/main/FMML_Course_Topic_8_Lab_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# Lab by V Vijay Vignesh
#
# vijay.vignesh@research.iiit.ac.in

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2024-03-31 09:20:51--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json.1’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   133MB/s    in 0.5s
#
# 2024-03-31 09:20:51 (133 MB/s) - ‘arxiv-paper-data.json.1’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False),
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split()
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 4702    1302.6617v1  Most optimal routing problems focus on minimiz...    cs
# 3456   1706.01604v2  We extend the theoretical analysis of a recent...    cs
# 6859   1706.09367v1  Machine Learning (ML) has been successfully ap...  stat
# 142    1711.03640v1  We study the performance of stochastically tra...  stat
# 1790   1609.06783v1  The Dirichlet process and its extension, the P...  stat
# ...             ...                                                ...   ...
# 24251   1112.5640v5  Manifold models provide low-dimensional repres...    cs
# 31122  1802.03943v1  This paper introduces an universal and structu...    cs
# 5638   1505.05208v1  Kernel matrices (e.g. Gram or similarity matri...  stat
# 30330  1711.11575v1  Although it is well believed for years that mo...    cs
# 7080   1710.00085v1  A standard recipe for spoken language recognit...  stat
#
#                                                    title  year  \
# 4702   Arriving on time: estimating travel time distr...  2013
# 3456   Hyperplane Clustering Via Dual Principal Compo...  2017
# 6859   autoBagging: Learning to Rank Bagging Workflow...  2017
# 142      Stochastic Deep Learning in Memristive Networks  2017
# 1790   Nonparametric Bayesian Topic Modelling with th...  2016
# ...                                                  ...   ...
# 24251   Learning Smooth Pattern Transformation Manifolds  2011
# 31122  Temporal and Volumetric Denoising via Quantile...  2018
# 5638   oASIS: Adaptive Column Sampling for Kernel Mat...  2015
# 30330             Relation Networks for Object Detection  2017
# 7080               Language-depedent I-Vectors for LRE15  2017
#
#                                                 keywords
# 4702   [minimizing, oftentimes, objective, probabilit...
# 3456   [theoretical, algorithm, principal, component,...
# 6859   [successfully, applications, techniques, succe...
# 142    [performance, stochastically, implemented, mem...
# 1790   [dirichlet, extension, stochastic, processes, ...
# ...                                                  ...
# 24251  [dimensional, representations, processing, ana...
# 31122  [introduces, universal, structure, preserving,...
# 5638   [similarity, essential, approaches, classifica...
# 30330  [relations, recognition, detection, recognizin...
# 7080   [recognition, uncertainty, extraction, importa...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 4702     [minimizing, oftentimes, objective, probabilit...
# 3456     [theoretical, algorithm, principal, component,...
# 6859     [successfully, applications, techniques, succe...
# 142      [performance, stochastically, implemented, mem...
# 1790     [dirichlet, extension, stochastic, processes, ...
#                                ...
# 20118    [measuring, effectiveness, corporate, environm...
# 1289     [meaningful, visualization, regularizer, regul...
# 703      [detection, fundamental, functions, applicatio...
# 6073     [unsupervised, representation, representation,...
# 26940    [important, egocentric, applications, algorith...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]),
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8829 words.
# Out of those 4560 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="0e0101c8-25e3-4470-9201-9ce05b1fe12f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0e0101c8-25e3-4470-9201-9ce05b1fe12f")) {                    Plotly.newPlot(                        "0e0101c8-25e3-4470-9201-9ce05b1fe12f",                        [{"x":["minimizing","composite","probability","framework","objective","estimating","correlations","developed","algorithms","efficiently","obtaining","scalability","francisco","illustrate","collected","statistical","algorithm","neighboring","leveraging","inference","distributions","oftentimes","compressed","continuous","principal","properties","experimental","evaluation","competitive","theoretical","separated","clustering","geometric","transferring","distributed","uniformly","associated","sequential","dramatically","hyperplanes","sufficiently","hyperplane","synthetic","optimization","correctness","component","automatically","automated","performance","systematically","techniques","exploiting","applications","successfully","replacement","metalearning","statistically","complexity","workflows","classification","typically","reproducibility","generalizability","successful","different","libraries","characterization","available","stochastically","variability","parameter","corrupted","minimized","implemented","stochastic","resolution","memristive","degradation","programming","characteristics","efficiency","nonparametric","analytics","designing","extension","hierarchical","efficient","modelling","particular","parametric","processes","community","dirichlet","equivalent","dimension","constraints","maximization","construct","considered","polynomial","monotonic","independent","approximate","important","practically","quadratic","correction","consistent","throughout","assumption","heterogeneous","empirical","canonical","variations","corrected","justifies","eigenvectors","estimation","regularized","characterizes","artificially","explained","blockmodel","partition","structure","autoencoders","resulting","dimensionality","combination","autoencoding","perspective","generative","reduction","presenting","neuroscience","impossible","transform","examining","automatic","therefore","evaluated","probabilistic","impairment","difficulties","projected","especially","kinematics","superpixels","segmentation","superpixel","consuming","understanding","coordinates","increasingly","interactively","graphically","requiring","effective","determined","advantage","previously","preserved","visualization","physically","structures","dimensions","dendrogram","distinguishable","underlying","euclidean","effectively","dimensional","embedding","visualized","outstanding","determine","attributes","presented","represent","demonstrated","generally","undesired","environment","generates","submission","disparities","correspondence","challenging","exceeding","benchmark","approaches","convolutional","inherently","noteworthy","explicitly","equipping","refinement","experimentation","traditional","composing"],"y":[48,16,173,496,160,60,30,192,617,149,35,39,2,65,90,166,797,14,43,195,114,3,20,112,39,217,337,291,112,172,15,156,69,9,98,21,92,72,21,2,21,3,120,308,16,87,188,95,889,12,407,85,431,91,9,1,9,238,1,528,130,4,7,80,722,11,28,304,2,15,129,16,14,113,142,110,1,19,113,101,149,23,19,48,70,83,396,56,283,32,99,57,19,65,67,134,29,86,129,54,18,150,114,335,14,33,28,89,12,61,37,150,18,86,11,5,6,195,43,8,6,14,0,21,364,18,138,46,116,2,60,111,101,27,8,14,72,12,202,152,121,153,2,40,17,102,6,10,192,5,43,149,11,57,4,0,42,267,40,88,93,14,29,10,124,44,0,4,106,38,120,184,104,2,4,66,68,156,125,94,83,2,131,62,8,2,29,269,6,211,394,360,17,3,63,2,23,21,160,5],"type":"bar"},{"x":["minimizing","composite","probability","framework","objective","estimating","cor ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4560,), (4560, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7933333333333333

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>Bias</span> <span style=''>Driven</span> <span style=''>Revision</span> <span style=''>of</span> <span style=''>Logical</span> <span style=''>Domain</span> <span style=''>Theories</span> <br/><br/><span style=''>The</span> <span style=''>theory</span> <span style=''>revision</span> <span style=''>problem</span> <span style=''>is</span> <span style=''>the</span> <span style=''>problem</span> <span style=''>of</span> <span style=''>how</span> <span style=''>best</span> <span style=''>to</span> <span style=''>go</span> <span style=''>about</span> <span style=''>revising</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>deficient</span> <span style=''>domain</span> <span style=''>theory</span> <span style=''>using</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style='background-color:rgba(0, 255, 0, 0.44);'>contained</span> <span style=''>in</span> <span style=''>examples</span> <span style=''>that</span> <span style=''>expose</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inaccuracies</span> <span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>we</span> <span style=''>present</span> <span style=''>our</span> <span style=''>approach</span> <span style=''>to</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>revision</span> <span style=''>problem</span> <span style=''>for</span> <span style='background-color:rgba(0, 255, 0, 1.0);'>propositional</span> <span style=''>domain</span> <span style=''>theories</span> <span style=''>The</span> <span style=''>approach</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>described</span> <span style=''>here</span> <span style=''>called</span> <span style=''>PTR</span> <span style=''>uses</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>probabilities</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>associated</span> <span style=''>with</span> <span style=''>domain</span> <span style=''>theory</span> <span style=''>elements</span> <span style=''>to</span> <span style='background-color:rgba(255, 0, 0, 0.36);'>numerically</span> <span style=''>track</span> <span style=''>the</span> <span style=''>flow</span> <span style=''>of</span> <span style=''>proof</span> <span style=''>through</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>This</span> <span style=''>allows</span> <span style=''>us</span> <span style=''>to</span> <span style=''>measure</span> <span style=''>the</span> <span style=''>precise</span> <span style=''>role</span> <span style=''>of</span> <span style=''>a</span> <span style=''>clause</span> <span style=''>or</span> <span style=''>literal</span> <span style=''>in</span> <span style=''>allowing</span> <span style=''>or</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286);'>preventing</span> <span style=''>a</span> <span style=''>(desired</span> <span style=''>or</span> <span style=''>undesired)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>derivation</span> <span style=''>for</span> <span style=''>a</span> <span style=''>given</span> <span style=''>example</span> <span style=''>This</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>information</span> <span style=''>is</span> <span style=''>used</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>efficiently</span> <span style=''>locate</span> <span style=''>and</span> <span style=''>repair</span> <span style=''>flawed</span> <span style=''>elements</span> <span style=''>of</span> <span style=''>the</span> <span style=''>theory</span> <span style=''>PTR</span> <span style=''>is</span> <span style=''>proved</span> <span style=''>to</span> <span style=''>converge</span> <span style=''>to</span> <span style=''>a</span> <span style=''>theory</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.4285714285714286 ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(0, 255, 0, 0.3);'>Stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Variational</span> <span style=''>Deep</span> <span style=''>Kernel</span> <span style=''>Learning</span> <br/><br/><span style=''>Deep</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>combines</span> <span style=''>the</span> <span style=''>non</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parametric</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>flexibility</span> <span style=''>of</span> <span style=''>kernel</span> <span style=''>methods</span> <span style=''>with</span> <span style=''>the</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>inductive</span> <span style=''>biases</span> <span style=''>of</span> <span style=''>deep</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>We</span> <span style=''>propose</span> <span style=''>a</span> <span style=''>novel</span> <span style=''>deep</span> <span style=''>kernel</span> <span style=''>learning</span> <span style=''>model</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>procedure</span> <span style=''>which</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>generalizes</span> <span style=''>deep</span> <span style=''>kernel</span> <span style=''>learning</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>approaches</span> <span style=''>to</span> <span style=''>enable</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>classification</span> <span style=''>multi</span> <span style=''>task</span> <span style=''>learning</span> <span style=''>additive</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>covariance</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>structures</span> <span style=''>and</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style=''>gradient</span> <span style=''>training</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Specifically</span> <span style=''>we</span> <span style=''>apply</span> <span style=''>additive</span> <span style=''>base</span> <span style=''>kernels</span> <span style=''>to</span> <span style=''>subsets</span> <span style=''>of</span> <span style=''>output</span> <span style=''>features</span> <span style=''>from</span> <span style=''>deep</span> <span style=''>neural</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>architectures</span> <span style=''>and</span> <span style=''>jointly</span> <span style=''>learn</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>of</span> <span style=''>the</span> <span style=''>base</span> <span style=''>kernels</span> <span style=''>and</span> <span style=''>deep</span> <span style=''>network</span> <span style=''>through</span> <span style=''>a</span> <span style=''>Gaussian</span> <span style=''>process</span> <span style=''>marginal</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>likelihood</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>objective</span> <span style=''>Within</span> <span style=''>this</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>framework</span> <span style=''>we</span> <span style=''>derive</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>efficient</span> <span style=''>form</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>stochastic</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>inference</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style='background-color:rgba(255, 0, 0, 0.5384615384615383);'>Variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>for</span> <span style=''>Marginal</span> <span style=''>MAP</span> <br/><br/><span style=''>Marginal</span> <span style=''>MAP</span> <span style=''>problems</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>notoriously</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>difficult</span> <span style=''>tasks</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>graphical</span> <span style=''>models</span> <span style=''>We</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>general</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615383);'>variational</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>for</span> <span style=''>solving</span> <span style=''>marginal</span> <span style=''>MAP</span> <span style=''>problems</span> <span style=''>in</span> <span style=''>which</span> <span style=''>we</span> <span style=''>apply</span> <span style='background-color:rgba(0, 255, 0, 0.33333333333333337);'>analogues</span> <span style=''>of</span> <span style=''>the</span> <span style=''>Bethe</span> <span style=''>tree</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>reweighted</span> <span style=''>and</span> <span style=''>mean</span> <span style=''>field</span> <span style='background-color:rgba(255, 0, 0, 0.4405594405594405);'>approximations</span> <span style=''>We</span> <span style=''>then</span> <span style=''>derive</span> <span style=''>a</span> <span style=''>mixed</span> <span style=''>message</span> <span style=''>passing</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>convergent</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>alternative</span> <span style=''>using</span> <span style=''>CCCP</span> <span style=''>to</span> <span style=''>solve</span> <span style=''>the</span> <span style=''>BP</span> <span style=''>type</span> <span style='background-color:rgba(255, 0, 0, 0.4405594405594405);'>approximations</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Theoretically</span> <span style=''>we</span> <span style=''>give</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>conditions</span> <span style=''>under</span> <span style=''>which</span> <span style=''>the</span> <span style=''>decoded</span> <span style=''>solution</span> <span style=''>is</span> <span style=''>a</span> <span style=''>global</span> <span style=''>or</span> <span style=''>local</span> <span style=''>optimum</span> <span style=''>and</span> <span style=''>obtain</span> <span style=''>novel</span> <span style=''>upper</span> <span style=''>bounds</span> <span style=''>on</span> <span style='background-color:rgba(0, 255, 0, 0.31666666666666665);'>solutions</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Experimentally</span> <span style=''>we</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>demonstrate</span> <span style=''>that</span> <span style=''>our</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>outperform</span> <span style=''>related</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>approaches</span> <span style=''>We</span> <span style=''>also</span> <span style=''>show</span> <span style=''>that</span> <span style=''>EM</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.5384615384615383);'>variational</span> <span style=''>EM</span> <span style=''>comprise</span> <span style=''>a</span> <span style=''>special</span> <span style=''>case</span> <span style=''>of</span> <span style=''>our</span> <span s ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Maximum</span> <span style=''>entropy</span> <span style=''>models</span> <span style=''>capture</span> <span style=''>melodic</span> <span style=''>styles</span> <br/><br/><span style=''>We</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>introduce</span> <span style=''>a</span> <span style=''>Maximum</span> <span style=''>Entropy</span> <span style=''>model</span> <span style=''>able</span> <span style=''>to</span> <span style=''>capture</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>statistics</span> <span style=''>of</span> <span style=''>melodies</span> <span style=''>in</span> <span style=''>music</span> <span style=''>The</span> <span style=''>model</span> <span style=''>can</span> <span style=''>be</span> <span style=''>used</span> <span style=''>to</span> <span style=''>generate</span> <span style=''>new</span> <span style=''>melodies</span> <span style=''>that</span> <span style=''>emulate</span> <span style=''>the</span> <span style=''>style</span> <span style=''>of</span> <span style=''>the</span> <span style=''>musical</span> <span style=''>corpus</span> <span style=''>which</span> <span style=''>was</span> <span style=''>used</span> <span style=''>to</span> <span style=''>train</span> <span style=''>it</span> <span style=''>Instead</span> <span style=''>of</span> <span style=''>using</span> <span style=''>the</span> <span style=''>n</span> <span style=''>body</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>of</span> <span style=''>(n</span> <span style=''>1)</span> <span style=''>order</span> <span style=''>Markov</span> <span style=''>models</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>traditionally</span> <span style=''>used</span> <span style=''>in</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>automatic</span> <span style=''>music</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>generation</span> <span style=''>we</span> <span style=''>use</span> <span style=''>a</span> <span style=''>k</span> <span style=''>nearest</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>neighbour</span> <span style=''>model</span> <span style=''>with</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>only</span> <span style=''>In</span> <span style=''>that</span> <span style=''>way</span> <span style=''>we</span> <span style=''>keep</span> <span style=''>the</span> <span style=''>number</span> <span style=''>of</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>parameters</span> <span style=''>low</span> <span style=''>and</span> <span style=''>avoid</span> <span style=''>over</span> <span style=''>fitting</span> <span style=''>problems</span> <span style=''>typical</span> <span style=''>of</span> <span style=''>Markov</span> <span style=''>models</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>long</span> <span style=''>range</span> <span style=''>musical</span> <span style=''>phrases</span> <span style=''>dont</span> <span style=''>need</span> <span style=''>to</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>explicitly</span> <span style=''>enforced</span> <span style=''>using</span> <span style=''>high</span> <span style=''>order</span> <span style=''>Markov</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>but</span> <span style=''>can</span> <span style=''>instead</span> <span style=''>emerge</span> <span style=''>from</span> <span style=''>multiple</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>competing</span> <span style=''>pairwise</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>interactions</span> <span style=''>We</span> <span style=''>validate</span> <span style=''>our</span> <span style=''>Maximum</span> <span style=''>E ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.1044404973357016)
# 	knowledge (0.1300177619893428)
# 	evaluation (0.10337477797513321)
# 	segmentation (0.06820603907637655)
# 	representation (0.13428063943161633)
# 	information (0.247246891651865)
# 	detection (0.12397868561278863)
# 	different (0.25648312611012436)
# 	convolutional (0.12788632326820604)
# 	recognition (0.1321492007104796)
#
# Some Statistics words are:
# 	convergence (0.12191435768261964)
# 	variables (0.1340050377833753)
# 	theoretical (0.15113350125944586)
# 	statistical (0.15919395465994962)
# 	distribution (0.17884130982367757)
# 	estimation (0.17229219143576827)
# 	algorithm (0.39848866498740554)
# 	dimensional (0.1929471032745592)
# 	inference (0.2040302267002519)
# 	regression (0.18186397984886649)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]),
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="75fd0945-0d32-4e69-bbbd-e726420f3299" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("75fd0945-0d32-4e69-bbbd-e726420f3299")) {                    Plotly.newPlot(                        "75fd0945-0d32-4e69-bbbd-e726420f3299",                        [{"x":["minimizing","composite","probability","framework","objective","estimating","correlations","developed","algorithms","efficiently","obtaining","scalability","francisco","illustrate","collected","statistical","algorithm","neighboring","leveraging","inference","distributions","oftentimes","compressed","continuous","principal","properties","experimental","evaluation","competitive","theoretical","separated","clustering","geometric","transferring","distributed","uniformly","associated","sequential","dramatically","hyperplanes","sufficiently","hyperplane","synthetic","optimization","correctness","component","automatically","automated","performance","systematically","techniques","exploiting","applications","successfully","replacement","metalearning","statistically","complexity","workflows","classification","typically","reproducibility","generalizability","successful","different","libraries","characterization","available","stochastically","variability","parameter","corrupted","minimized","implemented","stochastic","resolution","memristive","degradation","programming","characteristics","efficiency","nonparametric","analytics","designing","extension","hierarchical","efficient","modelling","particular","parametric","processes","community","dirichlet","equivalent","dimension","constraints","maximization","construct","considered","polynomial","monotonic","independent","approximate","important","practically","quadratic","correction","consistent","throughout","assumption","heterogeneous","empirical","canonical","variations","corrected","justifies","eigenvectors","estimation","regularized","characterizes","artificially","explained","blockmodel","partition","structure","autoencoders","resulting","dimensionality","combination","autoencoding","perspective","generative","reduction","presenting","neuroscience","impossible","transform","examining","automatic","therefore","evaluated","probabilistic","impairment","difficulties","projected","especially","kinematics","superpixels","segmentation","superpixel","consuming","understanding","coordinates","increasingly","interactively","graphically","requiring","effective","determined","advantage","previously","preserved","visualization","physically","structures","dimensions","dendrogram","distinguishable","underlying","euclidean","effectively","dimensional","embedding","visualized","outstanding","determine","attributes","presented","represent","demonstrated","generally","undesired","environment","generates","submission","disparities","correspondence","challenging","exceeding","benchmark","approaches","convolutional","inherently","noteworthy","explicitly","equipping","refinement","experimentation","traditional","composing","disparity","initialized","developments","surpassing","summation","convolution","architecture","extraction","distortion","optimally","constrained","aforementioned","outperform","theoretically","noticeably","competing","denoising","formulate","unavoidable","estimated","processing","recognition","acquisition","posterior","application","posteriori","outperformed","representation","detection","technologies","bandwidth","compression","transmission","encountered","directional","recognizing","combining","encodings","extensive","experiments","dictionary","continuity","literature","asymptotic","generalizes","generation","inception","distances","concentration","variation","empirically","dominated","conceptual","establish","functions","differ ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	blockmodel
# 	graphically
# 	dendrogram
# 	favourably
# 	discretisation
# 	maximising
# 	minimises
# 	nonconjugate
# 	supersparse
# 	disaggregation
# 	dendrograms
# 	capitalizing
# 	overlapped
# 	collinearity
# 	exponents
# 	subgaussian
# 	heteroscedastic
# 	quadratically
# 	conjugacy
# 	governing
# Some words which never appear in Statistics papers:
# 	francisco
# 	oftentimes
# 	kinematics
# 	superpixel
# 	noteworthy
# 	equipping
# 	barycenter
# 	relighting
# 	untrimmed
# 	localizing
# 	activitynet
# 	participation
# 	mutational
# 	transmitted
# 	normalize
# 	switchboard
# 	digitized
# 	unrolling
# 	extractive
# 	surpassed

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0571690614490985e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7491666666666666
