# %% [markdown]
# <a href="https://colab.research.google.com/github/sravani-200519/FMML2023/blob/main/mod3_lab4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **FOUNDATIONS OF MODERN MACHINE LEARNING, IIIT Hyderabad**
# ### MODULE: CLASSIFICATION-1
# ### LAB-4 : Understanding Cross-Validation and Standardization
# #### Module Coordinator: Jashn Arora
# ---

# %% [markdown]
# # **Section 1: Tweaking the parameters**

# %% [markdown]
# Let's stat the lab by writing knn code on a cancer detection dataset

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn
from sklearn.neighbors import KNeighborsClassifier
from sklearn import datasets

# %%
cancer = datasets.load_breast_cancer(as_frame=True)

# %%
cancer.target_names
# Out:
# array(['malignant', 'benign'], dtype='<U9')

# %%
cancer.frame
# Out:
#      mean radius  mean texture  mean perimeter  mean area  mean smoothness  \
# 0          17.99         10.38          122.80     1001.0          0.11840
# 1          20.57         17.77          132.90     1326.0          0.08474
# 2          19.69         21.25          130.00     1203.0          0.10960
# 3          11.42         20.38           77.58      386.1          0.14250
# 4          20.29         14.34          135.10     1297.0          0.10030
# ..           ...           ...             ...        ...              ...
# 564        21.56         22.39          142.00     1479.0          0.11100
# 565        20.13         28.25          131.20     1261.0          0.09780
# 566        16.60         28.08          108.30      858.1          0.08455
# 567        20.60         29.33          140.10     1265.0          0.11780
# 568         7.76         24.54           47.92      181.0          0.05263
#
#      mean compactness  mean concavity  mean concave points  mean symmetry  \
# 0             0.27760         0.30010              0.14710         0.2419
# 1             0.07864         0.08690              0.07017         0.1812
# 2             0.15990         0.19740              0.12790         0.2069
# 3             0.28390         0.24140              0.10520         0.2597
# 4             0.13280         0.19800              0.10430         0.1809
# ..                ...             ...                  ...            ...
# 564           0.11590         0.24390              0.13890         0.1726
# 565           0.10340         0.14400              0.09791         0.1752
# 566           0.10230         0.09251              0.05302         0.1590
# 567           0.27700         0.35140              0.15200         0.2397
# 568           0.04362         0.00000              0.00000         0.1587
#
#      mean fractal dimension  ...  worst texture  worst perimeter  worst area  \
# 0                   0.07871  ...          17.33           184.60      2019.0
# 1                   0.05667  ...          23.41           158.80      1956.0
# 2                   0.05999  ...          25.53           152.50      1709.0
# 3                   0.09744  ...          26.50            98.87       567.7
# 4                   0.05883  ...          16.67           152.20      1575.0
# ..                      ...  ...            ...              ...         ...
# 564                 0.05623  ...          26.40           166.10      2027.0
# 565                 0.05533  ...          38.25           155.00      1731.0
# 566                 0.05648  ...          34.12           126.70      1124.0
# 567                 0.07016  ...          39.42           184.60      1821.0
# 568                 0.05884  ...          30.37            59.16       268.6
#
#      worst smoothness  worst compactness  worst concavity  \
# 0             0.16220            0.66560           0.7119
# 1             0.12380            0.18660           0.2416
# 2             0.14440            0.42450           0.4504
# 3             0.20980            0.86630           0.6869
# 4             0.13740            0.20500           0.4000
# ..                ...                ...              ...
# 564           0.14100            0.21130           0.4107
# 565           0.11660            0.19220           0.3215
# 566           0.11390            0.30940           0.3403
# 567           0.16500            0.86810           0.9387
# 568           0.08996            0.06444           0.0000
#
#      worst concave points  worst symmetry  worst fractal dimension  target
# 0                  0.2654          0.4601                  0.11890       0
# 1                  0.1860          0.2750                  0.08902       0
# 2                  0.2430          0.3613                  0.08758       0
# 3                  0.2575          0.6638                  0.17300       0
# 4                  0.1625          0.2364                  0.07678       0
# ..                    ...             ...                      ...     ...
# 564                0.2216          0.2060                  0.07115       0
# 565                0.1628          0.2572                  0.06637       0
# 566                0.1418          0.2218                  0.07820       0
# 567                0.2650          0.4087                  0.12400       0
# 568                0.0000          0.2871                  0.07039       1
#
# [569 rows x 31 columns]

# %%
X = cancer.data
y = cancer.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 17)

# %% [markdown]
# ## Section 1.1: Changing Value of K
# Let's try to run the knn with different values of knn and compare the results

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 93.61702127659575
# [10, 12, 13, 14, 22, 24]

# %% [markdown]
# In this case, we see that the ideal number of neighbours can take any one of the values in the list [10,12,13,14,22,24].
# However, this only tells us the effectiveness of the KNN classifier only if we have the same train-test split considered above. It still does not tell us how well the algorithm would perform if the test set were different. The results would have been different if we had split the data differently.

# %% [markdown]
# ### AUC-ROC Curve

# %% [markdown]
# The AUC - ROC curve is a performance measurement for classification problems at various threshold settings. ROC is a probability curve and AUC represents the degree or measure of separability.
# It tells how much the model is capable of distinguishing between classes.
# The diagonal in the curve divides the ROC space. Points above the diagonal represent good classification results (better than random); points below the line represent bad results (worse than random).
# Higher the AUC, the better the model is at predicting 0 classes as 0 and 1 classes as 1.
#
# The ROC curve is plotted with the TPR (True Positive Rate) on the y-axis, and the FPR (False Positive Rate) on the x-axis.

# %%
## AUC-ROC
from sklearn.metrics import roc_curve
from sklearn.metrics import auc
import matplotlib.pyplot as plt

def plot_roc(y_test,predicted):
  y_scores = predicted
  fpr, tpr, threshold = roc_curve(y_test, y_scores)
  roc_auc = auc(fpr, tpr)
  plt.plot(fpr, tpr, 'b', label = 'AUC = %0.2f' % roc_auc)
  plt.legend(loc = 'lower right')
  plt.plot([0, 1], [0, 1],'r--')
  plt.xlim([0, 1])
  plt.ylim([0, 1])
  plt.ylabel('True Positive Rate')
  plt.xlabel('False Positive Rate')
  plt.title('Receiver Operating Characteristic')
  plt.show()

# %%
knn = KNeighborsClassifier(n_neighbors = 10)
knn.fit(X_train,y_train)
predictions = knn.predict(X_test)
plot_roc(y_test,predictions)

# %% [markdown]
# ## Section 1.2: KNN using a different train-test split

# %%
## Changing the random_state value here so that data is split differently
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 1089)

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 94.14893617021278
# [5, 7, 8]

# %% [markdown]
# As you can see, the model gives different results when we split the data differently. Here, it suggests that the ideal k value is 5, 7 or 8.

# %% [markdown]
# # **Section 2: Cross Validation**

# %% [markdown]
# As you saw in the above two cases with different train-test splits, there is a risk of overfitting on the test set because the parameters can be tweaked until the estimator performs optimally. This way, knowledge about the test set can “leak” into the model and evaluation metrics no longer report on generalization performance.
#
# Cross Validation is an important technique in Machine Learning to analyze the performance of a model on **unseen** data.
#
# There are different kinds of cross-validation methods: exhaustive and non-exhaustive.
# Exhaustive cross-validation methods are cross-validation methods which learn and test on all possible ways to divide the original sample into a training and a validation set.
# Non-exhaustive cross validation methods do not compute all ways of splitting the original sample.
#
# One of the most commonly cross-validation methods is **K-Fold Cross validation**. The procedure for K-Fold Cross Validation is as follows:
# 1. Split the dataset into k groups (typically without shuffling)
# 2. For each unique group:
#   a. Take the group as a hold out or test data set
#   b. Take the remaining groups as a training data set
#   c. Fit a model on the training set and evaluate it on the test set
#   d. Retain the evaluation score and discard the model
# 3. Summarize the performance of the model using the mean of model evaluation scores over all the folds.

# %% [markdown]
# Image source: https://scikit-learn.org/stable/modules/cross_validation.html
# ![Screenshot from 2021-12-13 09-37-46.png](data:image/png;base64,...)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.33, random_state = 17)

# %%
from sklearn.model_selection import KFold
from statistics import mean
kf = KFold(n_splits=10)
cv_scores = []
neighbors = []
for k in range(1,25):
  knn = KNeighborsClassifier(n_neighbors = k)
  neighbors.append(k)
  acclist = []
  for train_index, test_index in kf.split(X_train, y_train):
    x_train_fold, x_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
    y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]
    knn.fit(x_train_fold, y_train_fold)
    acclist.append(knn.score(x_test_fold, y_test_fold))
  cv_scores.append(mean(acclist))

# %%
Accuracy = [x*100 for x in cv_scores]

# plot misclassification error versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlabel('Number of neighbors')
plt.ylabel('Mean Cross-validation accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(optimal_ks)
# Out:
# [10, 12]

# %% [markdown]
# Note that the accuracy in the above case is not the accuracy on the test set. We plot the mean of the accuracies obtained during cross-validation, when we considered different splits of the training set.
#
# From the plot above, we can see that when the value of k is 10 or 12, our KNN model generalizes well to unseen data. Performing such cross validation gives us an idea about the parameters to choose when using a machine-learning algorithm.

# %%
## TASK-1:
## In the above case, we saw K-Fold cross validation, where we split the dataset into K consecutive folds without taking anything else into account.
## Stratified KFold is another strategy that is commonly used, which preserves the percentage of samples for each class in the folds.
## Implement Stratified KFold (refer Sklearn docs) and display the results you obtain

# %%
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score

# Create a StratifiedKFold instance
stratified_kfold = StratifiedKFold(n_splits=10)

# Lists to store results
stratified_cv_scores = []
stratified_neighbors = []

# Loop over different values of k
for k in range(1, 25):
    knn = KNeighborsClassifier(n_neighbors=k)
    stratified_neighbors.append(k)

    acclist = []

    # Perform Stratified K-Fold cross-validation
    for train_index, test_index in stratified_kfold.split(X_train, y_train):
        x_train_fold, x_test_fold = X_train.iloc[train_index], X_train.iloc[test_index]
        y_train_fold, y_test_fold = y_train.iloc[train_index], y_train.iloc[test_index]

        # Fit the model on the training set and evaluate on the test set
        knn.fit(x_train_fold, y_train_fold)
        y_pred = knn.predict(x_test_fold)
        acclist.append(accuracy_score(y_test_fold, y_pred))

    # Calculate the mean accuracy across folds for the current k
    stratified_cv_scores.append(mean(acclist))

# Convert accuracy scores to percentages
stratified_Accuracy = [x * 100 for x in stratified_cv_scores]

# Plot mean Stratified K-Fold cross-validation accuracy versus k
plt.figure(figsize=(10, 6))
plt.plot(stratified_neighbors, stratified_Accuracy)
plt.xlabel('Number of neighbors')
plt.ylabel('Mean Stratified K-Fold Cross-validation accuracy in %')
plt.show()

# Determine the best k
max_stratified_acc = max(stratified_Accuracy)
optimal_stratified_ks = [stratified_neighbors[i] for i, j in enumerate(stratified_Accuracy) if j == max_stratified_acc]
print(f"Optimal k values for Stratified K-Fold Cross-validation: {optimal_stratified_ks}")
# Out:
# Optimal k values for Stratified K-Fold Cross-validation: [5, 6]

# %% [markdown]
# # **Section 3: Standardization**

# %% [markdown]
# Scaling the data that we have available is a recommended pre-processing step when working with many machine learning algorithms. The scale and distribution of the data drawn from the domain may be different for each variable. Differences in the scales across input variables may increase the difficulty of the problem being modeled, and the model may suffer from poor performance during learning and sensitivity to input values resulting in higher generalization error.
#
# Standardization (also called z-score normalization) is one such scaling technique that transforms your data such that the resulting distribution has a mean of 0 and a standard deviation of 1.
#
# $$ \text{New (scaled) value} = {X - \mu \over \sigma}$$

# %%
X = cancer.data
y = cancer.target

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_scaled, y, test_size = 0.33, random_state = 17)

# %%
neighbors = []
scores_list = []

for k in range(1, 25):
    neighbors.append(k)
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train,y_train)
    scores = knn.score(X_test,y_test)
    scores_list.append(scores)

# %%
Accuracy = [x*100 for x in scores_list]
# plot Accuracy versus k
plt.figure(figsize = (10, 6))
plt.plot(neighbors, Accuracy)
plt.xlim([0, 25])
plt.xlabel('Number of neighbors')
plt.ylabel('Accuracy in %')
plt.show()

# %%
# determining the best k
max_acc = max(Accuracy)
optimal_ks = [neighbors[i] for i, j in enumerate(Accuracy) if j == max_acc]
print(max_acc)
print(optimal_ks)
# Out:
# 96.80851063829788
# [2]

# %%
## TASK-2:
## Plot a confusion matrix for the classification above on the scaled data (using the optimal value of k)
## Also print out the Precision, Recall and F1-score values

from sklearn.metrics import confusion_matrix, classification_report
import seaborn as sns

# Using the optimal k value obtained
optimal_k = optimal_ks[0]

# Create and train the KNN model with the optimal k
knn_optimal = KNeighborsClassifier(n_neighbors=optimal_k)
knn_optimal.fit(X_train, y_train)

# Make predictions on the test set
y_pred = knn_optimal.predict(X_test)

# Plot confusion matrix
plt.figure(figsize=(8, 6))
cm = confusion_matrix(y_test, y_pred)
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", cbar=False)
plt.title('Confusion Matrix')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# Print precision, recall, and F1-score
print("\nClassification Report:")
print(classification_report(y_test, y_pred))
# Out:
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.97      0.94      0.95        67
#            1       0.97      0.98      0.98       121
#
#     accuracy                           0.97       188
#    macro avg       0.97      0.96      0.96       188
# weighted avg       0.97      0.97      0.97       188

# %%
## TASK-3:
## Perform K-Fold Cross validation after standardizing the data. Display your results.

from sklearn.model_selection import cross_val_score
from sklearn.pipeline import make_pipeline

# Create a pipeline with StandardScaler and KNeighborsClassifier
model = make_pipeline(StandardScaler(), KNeighborsClassifier(n_neighbors=optimal_k))

# Perform K-Fold Cross Validation
cv_results = cross_val_score(model, X, y, cv=10, scoring='accuracy')

# Display the results
print("Cross Validation Results:")
for i, acc in enumerate(cv_results, start=1):
    print(f"Fold {i}: {acc * 100:.2f}%")

# Plot the results
plt.figure(figsize=(8, 6))
plt.boxplot(cv_results, vert=False)
plt.title('K-Fold Cross Validation Results')
plt.xlabel('Accuracy')
plt.show()

# Print the mean and standard deviation of the cross-validation results
print("\nMean Accuracy:", cv_results.mean() * 100)
print("Standard Deviation of Accuracy:", cv_results.std() * 100)
# Out:
# Cross Validation Results:
# Fold 1: 92.98%
# Fold 2: 94.74%
# Fold 3: 94.74%
# Fold 4: 98.25%
# Fold 5: 100.00%
# Fold 6: 96.49%
# Fold 7: 91.23%
# Fold 8: 96.49%
# Fold 9: 89.47%
# Fold 10: 91.07%
# Mean Accuracy: 94.54573934837093
# Standard Deviation of Accuracy: 3.1988792887455797

# %% [markdown]
# ### Questions to Think About and Answer
# 1. Instead of using cross-validation, we could also split our dataset into three sets- train, validation, and test set. The training proceeds on the training set, after which evaluation is done on the validation set, and when the experiment seems to be successful, final evaluation can be done on the test set.
# What do you think are the pros/cons of this method ?
# 2. Is K-Fold cross validation an exhaustive or non-exhaustive cross validation method ? Justify your answer.

# %% [markdown]
# # ANSWER FOR QUESTION 1:
#
#
#
#
# ##Pros:
#
# ###Simplicity:
#
#  The train-validation-test split is straightforward and easy to understand. It provides a clear separation of data for training, fine-tuning (validation), and final evaluation (test).
#
# ###Interpretability:
#
#  Results from the validation set can be used to make decisions about model adjustments or hyperparameter tuning, enhancing interpretability.
#
# ###Efficiency:
#
#  With a sufficiently large dataset, you can still achieve robust model evaluation without the need for extensive computational resources compared to certain cross-validation methods.
#
# ##Cons:
#
# ###Data Dependence:
#
#  The effectiveness of this approach heavily depends on the representativeness of each split. If the initial split is not representative, it may lead to overfitting or underfitting.
#
# ###Reduced Data for Training:
#
#  By allocating a portion of the data to the validation and test sets, there's less data available for training the model, potentially limiting its ability to generalize well.
#
# ###Randomness Impact:
#
# The randomness in the initial split can significantly affect the performance evaluation, especially with smaller datasets. It might lead to biased estimates of model performance.
#
# ###Not Suitable for Small Datasets:
#
# In cases where the dataset is small, splitting it into three sets might result in insufficient samples for training, validation, and testing, reducing the reliability of performance estimates.
#
# ##Conclusion:
#
# The choice between cross-validation and the train-validation-test split often depends on the dataset size, available computational resources, and the specific goals of the analysis. The train-validation-test split is more suitable for larger datasets, where efficiency and simplicity are prioritized, while cross-validation provides a more robust evaluation method, especially in scenarios with limited data.

# %% [markdown]
# # ANSWER FOR QUESTION 2:
#
# K-Fold Cross Validation is an exhaustive cross-validation method.
#
# In K-Fold Cross Validation, the dataset is divided into k subsets, and the model is trained and evaluated k times, each time using a different subset as the test set and the remaining data as the training set. This ensures that the model is tested on all possible combinations of training and test sets. It provides a more comprehensive assessment of the model's performance across different partitions of the data.
#
#
# In contrast, non-exhaustive cross-validation methods do not consider all possible ways of splitting the original sample. For example, in Leave-One-Out Cross Validation (LOOCV), only one data point is used as the test set in each iteration, and the model is trained on the remaining data. This is not considered exhaustive because it does not cover all possible combinations of training and test sets.
#
# Therefore, K-Fold Cross Validation is exhaustive as it systematically evaluates the model on all possible ways to divide the original sample into training and validation sets.

# %% [markdown]
# ### Useful Resources for further reading
# 1. Cross validation (scikit-learn): https://scikit-learn.org/stable/modules/cross_validation.html
# 2. Wikipedia: https://en.wikipedia.org/wiki/Cross-validation_(statistics)
# 3. Standardization: https://machinelearningmastery.com/standardscaler-and-minmaxscaler-transforms-in-python/
# 4. AUC-ROC : https://en.wikipedia.org/wiki/Receiver_operating_characteristic
